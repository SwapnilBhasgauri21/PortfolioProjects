# %% [raw]
# This Python script leverages the CoinMarketCap API to systematically retrieve and analyze cryptocurrency data. Facilitated by a modular design, it employs a dedicated function for repeated API calls, persistently appending results to a Pandas DataFrame. The script incorporates error-handling mechanisms, enhancing data retrieval reliability. Beyond data storage, Seaborn and Matplotlib visualize trends by grouping and calculating average percentage changes, offering insights into cryptocurrency market dynamics. With a focus on modularity, error resilience, and insightful visualization, the script stands as a versatile tool for cryptocurrency market data exploration and analysis within a project or research framework.

# %% [markdown]
# ## Cryptocurrency API Data Retrieval

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %% [markdown]
# ## Cryptocurrency Data Processing and DataFrame Creation

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10649
# 1    1027     Ethereum    ETH      ethereum              8058
# 2     825  Tether USDt   USDT        tether             68337
# 3    1839          BNB    BNB           bnb              1875
# 4      52          XRP    XRP           xrp              1176
# 5    5426       Solana    SOL        solana               562
# 6    3408         USDC   USDC      usd-coin             15578
# 7    2010      Cardano    ADA       cardano              1004
# 8    5805    Avalanche   AVAX     avalanche               598
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    
    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

# %% [markdown]
# ## Cryptocurrency Data Analysis and Trends Over Time

# %%
import os 
from time import time
from time import sleep

# %%
for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# /var/folders/b1/lcn6s67s5pj854gq4m63s7zc0000gn/T/ipykernel_4205/3878703673.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# API Runner completed
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# ...

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10649
# 1    1027     Ethereum    ETH      ethereum              8058
# 2     825  Tether USDt   USDT        tether             68337
# 3    1839          BNB    BNB           bnb              1875
# 4      52          XRP    XRP           xrp              1176
# 5    5426       Solana    SOL        solana               562
# 6    3408         USDC   USDC      usd-coin             15578
# 7    2010      Cardano    ADA       cardano              1004
# 8    5805    Avalanche   AVAX     avalanche               598
# 9      74     Dogecoin   DOGE      dogecoin               846
# 10   1958         TRON    TRX          tron               887
# 11   6636     Polkadot    DOT  polkadot-new               643
# 12   1975    Chainlink   LINK     chainlink              1509
# 13   3890      Polygon  MATIC       polygon              1163
# ...

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.25669                      -1.77591
# Ethereum                         0.20814                      -1.54781
# Tether USDt                     -0.01060                      -0.01385
# BNB                              0.58841                      -1.51642
# XRP                              0.08628                      -1.06331
# Solana                           0.94474                      -5.30416
# USDC                            -0.00166                      -0.00469
# Cardano                          0.36815                      -4.80042
# Avalanche                        0.12598                      -6.79572
# Dogecoin                         0.61050                      -0.13968
# TRON                             0.17834                       0.52652
# Polkadot                        -0.62217                      -5.55758
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.25669
#              quote.USD.percent_change_24h    -1.77591
#              quote.USD.percent_change_7d     -4.76978
#              quote.USD.percent_change_30d    15.64073
#              quote.USD.percent_change_60d    47.34199
#              quote.USD.percent_change_90d    53.32480
# Ethereum     quote.USD.percent_change_1h      0.20814
#              quote.USD.percent_change_24h    -1.54781
#              quote.USD.percent_change_7d     -5.65858
#              quote.USD.percent_change_30d    15.24865
#              quote.USD.percent_change_60d    41.01483
#              quote.USD.percent_change_90d    34.10194
# Tether USDt  quote.USD.percent_change_1h     -0.01060
#              quote.USD.percent_change_24h    -0.01385
#              quote.USD.percent_change_7d     -0.07788
#              quote.USD.percent_change_30d    -0.09342
#              quote.USD.percent_change_60d    -0.11945
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.25669
#             quote.USD.percent_change_24h  -1.77591
#             quote.USD.percent_change_7d   -4.76978
#             quote.USD.percent_change_30d  15.64073
#             quote.USD.percent_change_60d  47.34199
#             quote.USD.percent_change_90d  53.32480
# Ethereum    quote.USD.percent_change_1h    0.20814
#             quote.USD.percent_change_24h  -1.54781
#             quote.USD.percent_change_7d   -5.65858
#             quote.USD.percent_change_30d  15.24865
#             quote.USD.percent_change_60d  41.01483
#             quote.USD.percent_change_90d  34.10194
# Tether USDt quote.USD.percent_change_1h   -0.01060
#             quote.USD.percent_change_24h  -0.01385
#             quote.USD.percent_change_7d   -0.07788
#             quote.USD.percent_change_30d  -0.09342
#             quote.USD.percent_change_60d  -0.11945
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.set_index(index)
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#       values
# 0    0.25669
# 1   -1.77591
# 2   -4.76978
# 3   15.64073
# 4   47.34199
# 5   53.32480
# 6    0.20814
# 7   -1.54781
# 8   -5.65858
# 9   15.24865
# 10  41.01483
# 11  34.10194
# 12  -0.01060
# 13  -0.01385
# 14  -0.07788
# 15  -0.09342
# 16  -0.11945
# 17  -0.12149
# 18   0.58841
# 19  -1.51642
# 20   1.09189
# 21   0.49891
# 22  14.52804
# 23  10.72432
# 24   0.08628
# 25  -1.06331
# 26  -6.64622
# 27   3.69915
# 28  26.39717
# 29  22.76558
# 30   0.94474
# 31  -5.30416
# 32  -1.70216
# 33  30.61155
# 34 205.55041
# 35 265.12911
# 36  -0.00166
# 37  -0.00469
# 38   0.00595
# 39  -0.00029
# 40  -0.00389
# 41  -0.00645
# 42   0.36815
# 43  -4.80042
# 44  -0.81131
# 45  63.66226
# 46 140.22218
# 47 131.50799
# 48   0.12598
# 49  -6.79572
# 50  25.55072
# 51 102.07074
# 52 361.02944
# 53 350.69843
# 54   0.61050
# 55  -0.13968
# 56  -6.20280
# 57  15.67301
# 58  61.20624
# 59  51.82760
# 60   0.17834
# 61   0.52652
# 62  -4.50039
# 63   0.86709
# 64  15.21959
# ...

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#       values
# 0    0.25669
# 1   -1.77591
# 2   -4.76978
# 3   15.64073
# 4   47.34199
# 5   53.32480
# 6    0.20814
# 7   -1.54781
# 8   -5.65858
# 9   15.24865
# 10  41.01483
# 11  34.10194
# 12  -0.01060
# 13  -0.01385
# 14  -0.07788
# 15  -0.09342
# 16  -0.11945
# 17  -0.12149
# 18   0.58841
# 19  -1.51642
# 20   1.09189
# 21   0.49891
# 22  14.52804
# 23  10.72432
# 24   0.08628
# 25  -1.06331
# 26  -6.64622
# 27   3.69915
# 28  26.39717
# 29  22.76558
# 30   0.94474
# 31  -5.30416
# 32  -1.70216
# 33  30.61155
# 34 205.55041
# 35 265.12911
# 36  -0.00166
# 37  -0.00469
# 38   0.00595
# 39  -0.00029
# 40  -0.00389
# 41  -0.00645
# 42   0.36815
# 43  -4.80042
# 44  -0.81131
# 45  63.66226
# 46 140.22218
# 47 131.50799
# 48   0.12598
# 49  -6.79572
# 50  25.55072
# 51 102.07074
# 52 361.02944
# 53 350.69843
# 54   0.61050
# 55  -0.13968
# 56  -6.20280
# 57  15.67301
# 58  61.20624
# 59  51.82760
# 60   0.17834
# 61   0.52652
# 62  -4.50039
# 63   0.86709
# 64  15.21959
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      41689.35396 2023-12-17 16:23:58.288606
# 0  Bitcoin      41755.84937                        NaT
# 0  Bitcoin      41803.03007                        NaT
# 0  Bitcoin      41820.83817                        NaT
